# %% [markdown]
# # PROJET ML NIR 208

# %% [markdown]
# ## Importation des librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from tkinter import filedialog 
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # importation des données

# %%
excel_file= filedialog.askopenfilename(title="sélectionnez le fichier excel contenant les données", filetypes=[("Fichier.csv", "*.xlsx *.xls *.xlsm *.txt *.CSV")])

df=pd.read_csv(excel_file, sep=r'\s+', index_col=None)
df=df.reset_index()
df.columns.values[0]="data"
df.head()
# Out:
#    data  \
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4
#
# ...
